# %% [markdown]
# # Test Technique Stage

# %% [markdown]
# Bonjour et bienvenue à ce test technique dans le cadre de votre candidature pour un stage chez DASMR !
#
# Ce notebook a été conçu pour vous permettre de démontrer vos compétences en programmation, en analyse de données et en résolution de problèmes.
#
# Vous y trouverez plusieurs exercices et questions destinés à évaluer vos connaissances et votre aptitude à travailler sur des projets techniques.
#
# **Ce que vous devez faire :**
#
# - Prenez le temps de bien lire chaque question et les consignes associées.
# - Répondez en utilisant le langage Python, comme attendu.
# - Testez votre code pour vous assurer qu'il fonctionne correctement.
# - Pensez à sauvegarder régulièrement votre travail afin d’éviter toute perte.
# - Conservez les cellules contenant les résultats.
#
# **Ce que nous allons évaluer :**
#
# - Vos compétences en programmation et en analyse de données.
# - Votre capacité à résoudre des problèmes techniques.
# - La clarté et les commentaires dans votre code.
#
# **Durée :**
#
# Vous avez jusqu’à la veille de votre entretien pour terminer ce test. Merci de soumettre votre notebook complet avant la date limite.
#
# **Si vous avez des questions :**
#
# N'hésitez pas à nous contacter à l'adresse suivante assiat.mohamed@bpifrance.fr

# %% [markdown]
# # 1.Nettoyage des données <a class="anchor" id="partie1"></a>

# %% [markdown]
# ### 1.1 Description de la table

# %% [markdown]
# ### 1.2 Traitement des valeurs manquantes

# %% [markdown]
# ### 1.3 Traitement des valeurs aberrantes et atypiques

# %% [markdown]
# # 2.Preprocessing <a class="anchor" id="partie1"></a>

# %% [markdown]
# ### 2.1 Séparation X et y des jeux de données

# %% [markdown]
# #### Idées:
#
# - Pour les prédictions, nous allons utiliser dans un premier temps l'ensemble des données dont `ENERGYSTARScore` pour faire nos prédictions, puis on utilisera un autre jeu de données mais sans `ENERGYSTARScore`. L'interêt est de voir son impact sur nos données
# - Pour la target, on utilisera y= `SiteEnergyUse(kBtu)`et y= `log2pSiteEnergyUse(kBtu)` afin de voir l'impact d'avoir rendu normale la distribution de la target.

# %% [markdown]
# Afin de **tester notre meilleur modèle** sur des données "inconnues", nous allons mettre de côté une partie des données initiales qui ne seront pas inclusent dans les modèles intermédiaires. Nous allons donc spliter nos données pour obtenir un jeu d'entrainement et un jeu de test *(20% des données)* Nous réalisons ce split avec comme varaible cible ``SiteEnergyUse(kBtu)``

# %% [markdown]
# ### 2.2  One Hot Encoding & Standardisation

# %% [markdown]
# - On utlise le OneHotEncoder pour labeliser nos données catégorielles
#
# - Puis les données numériques doivent être standardisées pour entrer dans nos modèles de prédiction.
#
# - Ces opérations seront réalisées sur la target `SiteEnergyUse(kBtu)`

# %% [markdown]
# ### a/ One Hot Encoding

# %% [markdown]
# ### b/ Standardisation

# %% [markdown]
# # 3. Entrainement de plusieurs modèles et prédiction <a class="anchor" id="partie2"></a>

# %% [markdown]
# ### 3.1 Entrainement et modélisation de nos modèles

# %% [markdown]
# #### Pour entrainer un modèle, il y a trois choses à faire,
#
# - Choisir le type de modèle sur lequel vous voulez entrainer
# - Entrainer le modèle
# - Prédire des données

# %% [markdown]
# #### Faire un scoring

# %% [markdown]
# ### 3.2 Affichage des résultats et évaluation de nos modèles

# %% [markdown]
# # 4.Optimisation et entrainements de nos modèles <a class="anchor" id="partie3"></a>

# %% [markdown]
# ### 4.1 Features importantes

# %% [markdown]
# ### 4.2 Prédictions et évaluation de nos prédictions

# %% [markdown]
# # Conclusion, Remarques et observations
